# %%
import re
def is_alphanumeric(s):
    return bool(re.fullmatch(r'[A-Za-z0-9" "@_]{8}',s))
txt=input("enter a string:")
if is_alphanumeric(txt):
    print("the string contains mentioned characters")
else:c
# Out:
# enter a string: Abc12@71
# the string contains mentioned characters

# %%
import re
def is_alphanumeric(s):
    return bool(re.fullmatch(r'[A-Za-z0-9]{8}',s))
    #to check only letter
def only_letters(s):
    return bool(re.fullmatch(r'',s))
    #to check for space
def contains_space(s):
    return bool(re.fullmatch(r'[A-Za-z0-9 ]',s)
    #to check for upper case
def upper_case(s):
    return bool(re.fullmatch(r'[A-Z]+',s))
    #to check for lower case
def lower_case(s):
    return bool(re.fullmatch(r'[a-z]+',s))
    #to check for only digits
def only_digits(s):
    return bool(re.fullmatch(r'[0-9]+',s))
    #to check whether ends with a digit
def endswith_digits(s):
    return bool(re.fullmatch(r'\d2',s))
#to check valid email id
email=input("enter your email id:")
sp_check=
