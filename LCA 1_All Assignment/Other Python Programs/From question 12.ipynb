# %%
#Problem12_Online Store
product={"name":"Laptop","brand":"Dell","price":60000,"stock":10}
#to update stock to 25
product["stock"]=25
#to give a discount and change price to 55000
product["price"]=55000
#to add "color":"Silver"
product["color"]="Silver"
#to delete the "brand" key
del product["brand"]
#to display all keys
print(product.keys())
#to display all values
print(product.values())

#Problem13_Movie Collection
movies=["Avatar","Titanic","Inception","Joker","Interstellar"]
#to add "Avengers"
movies.append("Avengers")
#to insert Dangal at position 2
movies.insert(1,"Dangal")
#to remove "Joker"
movies.remove("Joker")
#to replace Titanic with 3 Idiots
movies[1] = "3 Idiots"
#to display the first 4 movies
print(movies[:4])
#to display the last 2 movies
print(movies[-2:])
#to find the number of movies
print(len(movies))

#Problem14_Personal Profile
info={"Name":"Watson","Age":19,"City":"Banglore","College":"Christ","Course":"Human Characteristic Analysis"}
#to add hobby
info["hobby"]="Violin"
#to update city
info["City"]="Pune"
#to delete the hobby
del info["hobby"]
#to display only the keys
print(info.keys())
#to display only the values
print(info.values())
#to display the complete profile
print(info)
# Out:
# dict_keys(['name', 'price', 'stock', 'color'])
# dict_values(['Laptop', 55000, 25, 'Silver'])
